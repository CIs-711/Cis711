# %% [markdown]
# **Assignment 3 Reading Input Data**
#
# *Done by Alaa Abu Qtaish, Anbraa Zaid Al Jamal, Anoud Hossam Khazaa'lah, Mohammed Atros*

# %%
# importing important packages 
import pandas as pd
import numpy as np
import io
import zipfile
from scipy.io import loadmat
from scipy.io import savemat
import matplotlib.pyplot as plt

# %%
# reading jump_olympics csv file  into df1
path = "Data/Ch1/jump-olympics.csv"
df1 = pd.read_csv(path)
# showing first five rows of df1
df1.head()
# Out:
#    year  Distance sex
# 0  1911      3.29   F
# 1  1914      3.28   F
# 2  1916      3.14   F
# 3  1918      3.08   F
# 4  1924      3.07   F

# %%
# reading Power-gain xls file  into df2  
path2 = "Data/Ch1/powerGain.xls"
#path2 = "Data/Ch1/Chronic.xls"
df2 = pd.read_excel(path2 , 'Sheet1', skiprows = 2)
# Showing last five rows of df2
df2.tail()
# Out:
#     person  pretest  post-test
# 15      16    105.9      101.2
# 16      17     84.4       78.2
# 17      18    103.9       99.7
# 18      19    105.9      100.8
# 19      20     95.4       91.2

# %%
# the path to the zipped archive 
path3 = 'Data/GLM_data.zip'

# %%
myzipfile = zipfile.ZipFile(path3)
#file = myzipfile.open(r'GLM_data/grades.csv')
#df3 = pd.read_csv(file)
# extract the requested file from the archive, as a pandas XLS-file
xlsfile = myzipfile.open(r'GLM_data/Table 2.8 Waist loss.xls')
# read the xls-file into df3
xls = pd.ExcelFile(xlsfile)
df3  = xls.parse('Sheet1', skiprows=2)
df3
# Out:
#     man  before  after
# 0     1   100.8   97.0
# 1     2   102.0  107.5
# 2     3   105.9   97.0
# 3     4   108.0  108.0
# 4     5    92.0   84.0
# 5     6   116.7  111.5
# 6     7   110.2  102.5
# 7     8   135.0  127.5
# 8     9   123.5  118.5
# 9    10    95.0   94.2
# 10   11   105.0  105.0
# 11   12    85.0   82.4
# 12   13   107.2   98.2
# 13   14    80.0   83.6
# 14   15   115.1  115.0
# 15   16   103.5  103.0
# 16   17    82.0   80.0
# 17   18   101.5  101.5
# 18   19   103.5  102.6
# 19   20    93.0   93.0

# %%
# Plotting a matlab file 

# creating data for the matlab file 

x=2*np.round(np.random.randn(200),2)+2
y=4*np.round(np.random.randn(200,1),2)+2
a=100*np.round(np.random.randn(200,200),2)+2

#Creating a dictionary for the matlab file 

mat_dict={'x':x,'y':y,'a':a}
savemat('Data/data.mat',mat_dict)

#loading the matlab file as a dictionary

mat=loadmat('Data/data.mat')

#extracting data from the dictionary

x_data=mat['x']
y_data=mat['y']
a_data=mat['a']

# defining z-axis range, the color map and plotting 
cp=plt.pcolor(x_data,y_data,a_data, cmap='jet', vmin=0, vmax=5000)
plt.colorbar(cp)
plt.title('Plotting a matlab file')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# <ipython-input-23-fa4065c5f449>:25: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cp=plt.pcolor(x_data,y_data,a_data, cmap='jet', vmin=0, vmax=5000)
# Text(0, 0.5, 'y-axis')
